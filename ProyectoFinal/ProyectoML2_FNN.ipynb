# %% [markdown]
# <a href="https://colab.research.google.com/github/eunrod16/MachineDeepLearning/blob/master/ProyectoML2_FNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········

# %% [markdown]
# # Data AirBnb in NY
# El ejercicio corresponde a obtener la clasificación de noches por año mayores a 100 en un lugar de AirAnb en New York. Los datos relevantes son precio, número de calificaciones, calificaciones por mes, tipo de habitación y listado de hosts.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("/content/drive/My Drive/AB_NYC_2019.csv", encoding='latin-1') 

data.head()

data.describe()
# Out:
#                  id  ...  availability_365
# count  4.889500e+04  ...      48895.000000
# mean   1.901714e+07  ...        112.781327
# std    1.098311e+07  ...        131.622289
# min    2.539000e+03  ...          0.000000
# 25%    9.471945e+06  ...          0.000000
# 50%    1.967728e+07  ...         45.000000
# 75%    2.915218e+07  ...        227.000000
# max    3.648724e+07  ...        365.000000
#
# [8 rows x 10 columns]

# %%
import numpy as np

rs = np.random.RandomState(0)
df = data
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col1 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col3 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col4 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col5 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col7 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col8 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row0_col9 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col0 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col2 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col3 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col5 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col6 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col7 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col8 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row1_col9 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col5 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col6 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col7 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col8 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col1 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col5 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col6 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col7 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row3_col9 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col2 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col5 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col6 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col7 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col8 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row4_col9 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col0 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col1 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col4 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col6 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col8 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_abc47dda_e8a9_11e9_84bd_0242ac1c0002row5_col9 {
#             background-color:  #6b8df0;
#             color:  #000000;

# %%
drop_colums=['name','host_name','neighbourhood',"neighbourhood_group",'last_review',"host_id","id"]
data = data.drop(drop_colums,axis=1)

# %%
data.head()
df = data
from sklearn.preprocessing import LabelEncoder
encod = LabelEncoder()
df['room_type_encoded'] = encod.fit_transform(df.room_type)
df = df.fillna(0)
#private 1 entire 0
df = df.drop(["room_type"],axis=1)
df.head()
# Out:
#    latitude  longitude  ...  availability_365  room_type_encoded
# 0  40.64749  -73.97237  ...               365                  1
# 1  40.75362  -73.98377  ...               355                  0
# 2  40.80902  -73.94190  ...               365                  1
# 3  40.68514  -73.95976  ...               194                  0
# 4  40.79851  -73.94399  ...                 0                  0
#
# [5 rows x 9 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),
            vmin=-1,
            cmap='coolwarm',
            annot=True);

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.nn.functional as F

# %%
#x_train = df.drop('availability_365',axis=1)

x_train = df[df.columns[6:8]]
#y_train = df[df.columns[1:2]]
y_train =df[df.columns[7:8]]
y_train["availability_365"] =y_train["availability_365"].apply(lambda x: 1 if x > 100 else 0)
y_train.head()
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.25, random_state = 1)
x_train.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#        calculated_host_listings_count  availability_365
# 7842                                4               102
# 44595                               1                 0
# 47241                               1                12
# 41192                               2               230
# 30522                               2               163

# %% [markdown]
# # FNN

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_train = torch.FloatTensor(x_train)
y_train = torch.FloatTensor(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
x_test = torch.FloatTensor(x_test)
y_test = torch.FloatTensor(y_test)

# %%
def accuracy(test_output, labels):
    num_correct = 0
    preds = torch.round(test_output.squeeze())
    correct_tensor = preds.eq(labels.float().view_as(preds))
    correct = np.squeeze(correct_tensor.numpy())
    num_correct += np.sum(correct)
    """"rounded_preds = torch.round(preds)
    correct = (rounded_preds == y).float() 
    acc = correct.sum() / len(correct)"""
    return num_correct/len(correct)

# %%
def checkpointModel():
    torch.save(model.state_dict(), "bestModel.model")
    print("Checkpoint saved")

# %%
class FeedPlease(nn.Module):
        def __init__(self, inputsize, hiddensize):
            super(FeedPlease, self).__init__()
            self.inputsize = inputsize
            self.hiddensize  = hiddensize
            self.h1 = nn.Linear(self.inputsize, self.hiddensize)
            self.relu = nn.ReLU()
            self.h2 = nn.Linear(self.hiddensize, 1)
            self.sigmoid = nn.Sigmoid()
            self.dropout = nn.Dropout(0.3)
        def forward(self, x):
            x = self.h1(x)
            x = self.relu(x)
            x = self.h2(x)
            x = self.dropout(x)
            x = self.sigmoid(x)
            return x

# %% [markdown]
# ## Entrenamiento

# %%
model = FeedPlease(2,3)

criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.2, momentum = 0.9,nesterov = True, weight_decay= 1e-6)
errores = []
model.train()
epoch = 20
for epoch in range(epoch):
    optimizer.zero_grad()
    y_hat = model(x_train)
    loss = criterion(y_hat.squeeze(), y_train)
    acc = accuracy(y_hat.squeeze(), y_train)
    loss.backward()
    optimizer.step()
    errores.append(loss.item())
    print('Epoch {}: train loss: {}'.format(epoch, loss.item()),' Accuracy: {}'.format(acc))
checkpointModel()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([36671, 1])) that is different to the input size (torch.Size([36671])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 0: train loss: 0.24679192900657654  Accuracy: 0.6097733904174961
# Epoch 1: train loss: 0.24639855325222015  Accuracy: 0.6097733904174961
# Epoch 2: train loss: 0.24582543969154358  Accuracy: 0.6097733904174961
# Epoch 3: train loss: 0.24519795179367065  Accuracy: 0.6097733904174961
# Epoch 4: train loss: 0.2443562000989914  Accuracy: 0.6097733904174961
# Epoch 5: train loss: 0.24351438879966736  Accuracy: 0.6097733904174961
# Epoch 6: train loss: 0.24287311732769012  Accuracy: 0.6097733904174961
# Epoch 7: train loss: 0.24240905046463013  Accuracy: 0.6097733904174961
# Epoch 8: train loss: 0.2420624941587448  Accuracy: 0.6097733904174961
# Epoch 9: train loss: 0.24180641770362854  Accuracy: 0.6097733904174961
# Epoch 10: train loss: 0.24175222218036652  Accuracy: 0.6097733904174961
# Epoch 11: train loss: 0.24182379245758057  Accuracy: 0.6097733904174961
# Epoch 12: train loss: 0.24186907708644867  Accuracy: 0.6097733904174961
# Epoch 13: train loss: 0.24188797175884247  Accuracy: 0.6097733904174961
# Epoch 14: train loss: 0.2420053333044052  Accuracy: 0.6097733904174961
# Epoch 15: train loss: 0.2419966757297516  Accuracy: 0.6097733904174961
# Epoch 16: train loss: 0.2420225590467453  Accuracy: 0.6097733904174961
# Epoch 17: train loss: 0.24202679097652435  Accuracy: 0.6097733904174961
# Epoch 18: train loss: 0.24199160933494568  Accuracy: 0.6097733904174961
# Epoch 19: train loss: 0.24196749925613403  Accuracy: 0.6097733904174961
# Checkpoint saved

# %% [markdown]
# ## Evaluación

# %%
from sklearn.metrics import f1_score

# %%
checkpoint = torch.load("bestModel.model")
model = FeedPlease(2,3)
model.load_state_dict(checkpoint)
model.eval()
#model.eval()
optimizer.zero_grad()
y_hat = model(x_test)
loss = criterion(y_hat.squeeze(), y_test)
acc = accuracy(y_hat.squeeze(), y_test)
print('Train loss: {}'.format(loss.item()),' Accuracy: {}'.format(acc),
      ' F1 Score: {}'.format(f1_score(y_hat.squeeze().detach().numpy()> 0.5, y_test.detach().numpy(), average='macro')  ))
loss.backward()
optimizer.step()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([12224, 1])) that is different to the input size (torch.Size([12224])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Train loss: 0.24067381024360657  Accuracy: 0.6061027486910995  F1 Score: 0.3773748280955534

# %%
fig,ax = plt.subplots(figsize=(5,5))
ax.set_ylabel('error')
ax.set_xlabel('Iterations')
ax.set_title('Comportamiento de Error')
_=ax.plot(range(len(errores)),errores,'g')

# %% [markdown]
# ## Conclusiones
#
#
# *   Es importante que los datos tenga un buen porcentaje de correlación entre ellos sino el aprendizaje será demasiado lento
# *   La cantidad de datos debe ser mayor a 10000 para que de igual manera no exista overfitting en el aprendizaje
# * Es importante regularizar la data con dropout.
# * Relu es una buena función de activación de capa intermedia y Sigmoid una buena función de activación de capa final. Todo esto para resolver un problema de clasificación
